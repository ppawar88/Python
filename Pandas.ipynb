# %%
import pandas as pd

# %% [markdown]
# ** Pandas Series **

# %%
series_1 = pd.Series([6,7,8,9,2,3,4,5])
series_1= series_1.apply(lambda x : x**2)
series_1
# Out:
# 0    36
# 1    49
# 2    64
# 3    81
# 4     4
# 5     9
# 6    16
# 7    25
# dtype: int64

# %%
series_2 = series_1

# %%
series_3= series_1.append(series_2)

# %%
series_4 = series_3.reset_index(drop=True)
series_4[0]
# Out:
# 36

# %%
series_4[5] = None

# %%
series_4.fillna(method="backfill")
# Out:
# 0    36.00
# 1    49.00
# 2    64.00
# 3    81.00
# 4     4.00
# 5    16.00
# 6    16.00
# 7    25.00
# 8    36.00
# 9    49.00
# 10   64.00
# 11   81.00
# 12    4.00
# 13    9.00
# 14   16.00
# 15   25.00
# dtype: float64

# %%
series_4.fillna(method="ffill")
# Out:
# 0    36.00
# 1    49.00
# 2    64.00
# 3    81.00
# 4     4.00
# 5     4.00
# 6    16.00
# 7    25.00
# 8    36.00
# 9    49.00
# 10   64.00
# 11   81.00
# 12    4.00
# 13    9.00
# 14   16.00
# 15   25.00
# dtype: float64

# %%
series_4.aggregate(func="sum")
# Out:
# 559.0

# %%
series_4.aggregate(func="max")
# Out:
# 81.0

# %%
series_4.all(axis=0)
# Out:
# True

# %%
n = 5
s1 = pd.Series(data=range(1,n+1))
print(s1.values)
s2 = s1.apply(lambda x : x**2)
print(s2)
s3 = pd.Series(data=s2.values, index=s1.values)
print (s3)
# Out:
# [1 2 3 4 5]
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# dtype: int64

# %%
s4 = pd.Series(data=s1.values, index=s2.values)
s4
# Out:
# 1     1
# 4     2
# 9     3
# 16    4
# 25    5
# dtype: int32

# %%
df = pd.read_csv('DataSet/forestfires.csv')
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 0    7  5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00
# 1    7  4   oct  tue 90.60  35.40 669.10  6.70 18.00  33  0.90  0.00  0.00
# 2    7  4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00
# 3    8  6   mar  fri 91.70  33.30  77.50  9.00  8.30  97  4.00  0.20  0.00
# 4    8  6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00
# 5    8  6   aug  sun 92.30  85.30 488.00 14.70 22.20  29  5.40  0.00  0.00
# 6    8  6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00
# 7    8  6   aug  mon 91.50 145.40 608.20 10.70  8.00  86  2.20  0.00  0.00
# 8    8  6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00
# 9    7  5   sep  sat 92.50  88.00 698.60  7.10 22.80  40  4.00  0.00  0.00
# 10   7  5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00
# ...

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.20 26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 1  7  4   oct  tue 90.60 35.40 669.10 6.70 18.00  33  0.90  0.00  0.00
# 2  7  4   oct  sat 90.60 43.70 686.90 6.70 14.60  33  1.30  0.00  0.00
# 3  8  6   mar  fri 91.70 33.30  77.50 9.00  8.30  97  4.00  0.20  0.00
# 4  8  6   mar  sun 89.30 51.30 102.20 9.60 11.40  99  1.80  0.00  0.00

# %%
df.tail()
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 512  4  3   aug  sun 81.60  56.70 665.60  1.90 27.80  32  2.70  0.00  6.44
# 513  2  4   aug  sun 81.60  56.70 665.60  1.90 21.90  71  5.80  0.00 54.29
# 514  7  4   aug  sun 81.60  56.70 665.60  1.90 21.20  70  6.70  0.00 11.16
# 515  1  4   aug  sat 94.40 146.00 614.70 11.30 25.60  42  4.00  0.00  0.00
# 516  6  3   nov  tue 79.50   3.00 106.70  1.10 11.80  31  4.50  0.00  0.00

# %%
df.take([3],axis=0)  # fetch 3 row absed on index
# Out:
#    X  Y month  day  FFMC   DMC    DC  ISI  temp  RH  wind  rain  area
# 3  8  6   mar  fri 91.70 33.30 77.50 9.00  8.30  97  4.00  0.20  0.00

# %%
df.take([3,4], axis=1).head(2) #fetch 3 & 4 column data of all rows
# Out:
#    day  FFMC
# 0  fri 86.20
# 1  tue 90.60

# %%
print(df.describe())
print(df.columns)
print(df.shape)
# Out:
#            X      Y   FFMC    DMC     DC    ISI   temp     RH   wind   rain  \
# count 517.00 517.00 517.00 517.00 517.00 517.00 517.00 517.00 517.00 517.00
# mean    4.67   4.30  90.64 110.87 547.94   9.02  18.89  44.29   4.02   0.02
# std     2.31   1.23   5.52  64.05 248.07   4.56   5.81  16.32   1.79   0.30
# min     1.00   2.00  18.70   1.10   7.90   0.00   2.20  15.00   0.40   0.00
# 25%     3.00   4.00  90.20  68.60 437.70   6.50  15.50  33.00   2.70   0.00
# 50%     4.00   4.00  91.60 108.30 664.20   8.40  19.30  42.00   4.00   0.00
# 75%     7.00   5.00  92.90 142.40 713.90  10.80  22.80  53.00   4.90   0.00
# max     9.00   9.00  96.20 291.30 860.60  56.10  33.30 100.00   9.40   6.40
#
#          area
# count  517.00
# mean    12.85
# std     63.66
# min      0.00
# 25%      0.00
# 50%      0.52
# 75%      6.57
# max   1090.84
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')
# (517, 13)

# %% [markdown]
# ** Different Ways of fetching rows/columns **

# %%
print(type(df.iloc[0]))
df.iloc[0] #Gives Series
# Out:
# <class 'pandas.core.series.Series'>
# X           7
# Y           5
# month     mar
# day       fri
# FFMC    86.20
# DMC     26.20
# DC      94.30
# ISI      5.10
# temp     8.20
# RH         51
# wind     6.70
# rain     0.00
# area     0.00
# Name: 0, dtype: object

# %%
print(type(df.iloc[0:1]))
df.iloc[0:1] # Gived Data Frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    X  Y month  day  FFMC   DMC    DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.20 26.20 94.30 5.10  8.20  51  6.70  0.00  0.00

# %%
df[1::2].head(10)
# Out:
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 1   7  4   oct  tue 90.60  35.40 669.10  6.70 18.00  33  0.90  0.00  0.00
# 3   8  6   mar  fri 91.70  33.30  77.50  9.00  8.30  97  4.00  0.20  0.00
# 5   8  6   aug  sun 92.30  85.30 488.00 14.70 22.20  29  5.40  0.00  0.00
# 7   8  6   aug  mon 91.50 145.40 608.20 10.70  8.00  86  2.20  0.00  0.00
# 9   7  5   sep  sat 92.50  88.00 698.60  7.10 22.80  40  4.00  0.00  0.00
# 11  7  5   sep  sat 92.80  73.20 713.00 22.60 19.30  38  4.00  0.00  0.00
# 13  6  5   sep  mon 90.90 126.50 686.50  7.00 21.30  42  2.20  0.00  0.00
# 15  6  5   sep  fri 93.30 141.20 713.90 13.90 22.90  44  5.40  0.00  0.00
# 17  8  5   oct  mon 84.90  32.80 664.20  3.00 16.70  47  4.90  0.00  0.00
# 19  6  4   apr  sat 86.30  27.40  97.10  5.10  9.30  44  4.50  0.00  0.00

# %%
df[df.index % 2 == 0] #Even index position row
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 0    7  5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00
# 2    7  4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00
# 4    8  6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00
# 6    8  6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00
# 8    8  6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00
# 10   7  5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00
# 12   6  5   aug  fri 63.50  70.80 665.30  0.80 17.00  72  6.70  0.00  0.00
# 14   6  5   sep  wed 92.90 133.30 699.60  9.20 26.40  21  4.50  0.00  0.00
# 16   5  5   mar  sat 91.70  35.80  80.80  7.80 15.10  27  5.40  0.00  0.00
# 18   6  4   mar  wed 89.20  27.90  70.80  6.30 15.90  35  4.00  0.00  0.00
# 20   6  4   sep  tue 91.00 129.50 692.60  7.00 18.30  40  2.70  0.00  0.00
# ...

# %%
df["day"].head(2)  # returns Series, because of only one column fetch
# Out:
# 0    fri
# 1    tue
# Name: day, dtype: object

# %%
# returns DF , becase of 2 D array use to fecth data, so python assume few more rows can be fecth hence DF returns
df[["day"]].head(2)
# Out:
#    day
# 0  fri
# 1  tue

# %%
df[["X","day"]].head(2) #Multiple Column
# Out:
#    X  day
# 0  7  fri
# 1  7  tue

# %%
df.iloc[:,[2,3,4]].head() # fetch all rows of column 3,4,5
# Out:
#   month  day  FFMC
# 0   mar  fri 86.20
# 1   oct  tue 90.60
# 2   oct  sat 90.60
# 3   mar  fri 91.70
# 4   mar  sun 89.30

# %%
df1 = df.set_index("X")

# %% [markdown]
# ** iloc = Used to fecthed index based / Position Based values - irrespective of custom index ** <br>
# ** loc = Used for fecthed data based on label or index value - in case of custom index it will return specific value of index **

# %%
df1.iloc[[7,8]]
# Out:
#    Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# X
# 8  6   aug  mon 91.50 145.40 608.20 10.70  8.00  86  2.20  0.00  0.00
# 8  6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00

# %%
df1.loc[[7,8]]
# Out:
#     Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# X
# 7   5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00   0.00
# 7   4   oct  tue 90.60  35.40 669.10  6.70 18.00  33  0.90  0.00   0.00
# 7   4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00   0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 22.80  40  4.00  0.00   0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00   0.00
# 7   5   sep  sat 92.80  73.20 713.00 22.60 19.30  38  4.00  0.00   0.00
# 7   4   jun  sun 94.30  96.30 200.00 56.10 21.00  44  4.50  0.00   0.00
# 7   4   aug  sat 90.20 110.90 537.40  6.20 19.50  43  5.80  0.00   0.00
# 7   4   aug  sat 93.50 139.40 594.20 20.30 23.70  32  5.80  0.00   0.00
# 7   4   aug  sun 91.40 142.40 601.40 10.60 16.30  60  5.40  0.00   0.00
# 7   4   sep  fri 92.40 117.90 668.00 12.20 19.00  34  5.80  0.00   0.00
# 7   4   sep  mon 90.90 126.50 686.50  7.00 19.40  48  1.30  0.00   0.00
# ...

# %% [markdown]
# **Sorting**

# %%
df.sort_index(ascending=False).head()
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 516  6  3   nov  tue 79.50   3.00 106.70  1.10 11.80  31  4.50  0.00  0.00
# 515  1  4   aug  sat 94.40 146.00 614.70 11.30 25.60  42  4.00  0.00  0.00
# 514  7  4   aug  sun 81.60  56.70 665.60  1.90 21.20  70  6.70  0.00 11.16
# 513  2  4   aug  sun 81.60  56.70 665.60  1.90 21.90  71  5.80  0.00 54.29
# 512  4  3   aug  sun 81.60  56.70 665.60  1.90 27.80  32  2.70  0.00  6.44

# %%
df.sort_values(by=["FFMC","temp"]).head(10)
# Out:
#      X  Y month  day  FFMC   DMC     DC  ISI  temp   RH  wind  rain  area
# 379  4  5   jan  sun 18.70  1.10 171.40 0.00  5.20  100  0.90  0.00  0.00
# 312  2  4   sep  sun 50.40 46.20 706.60 0.40 12.20   78  6.30  0.00  0.00
# 299  6  5   jun  sat 53.40 71.00 233.80 0.40 10.60   90  2.70  0.00  0.00
# 12   6  5   aug  fri 63.50 70.80 665.30 0.80 17.00   72  6.70  0.00  0.00
# 199  2  4   sep  mon 63.50 70.80 665.30 0.80 22.60   38  3.60  0.00 11.32
# 130  4  6   feb  sat 68.20 21.50  87.20 0.80 15.40   40  2.70  0.00  0.00
# 97   3  4   mar  sat 69.00  2.40  15.50 0.70 17.40   24  5.40  0.00  0.00
# 463  6  5   feb  tue 75.10  4.40  16.20 1.90  4.60   82  6.30  0.00  5.39
# 464  6  4   feb  tue 75.10  4.40  16.20 1.90  5.10   77  5.40  0.00  2.14
# 465  2  2   feb  sat 79.50  3.60  15.30 1.80  4.60   59  0.90  0.00  6.84

# %%
df.set_index("X")
# Out:
#     Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# X
# 7   5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00
# 7   4   oct  tue 90.60  35.40 669.10  6.70 18.00  33  0.90  0.00  0.00
# 7   4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00
# 8   6   mar  fri 91.70  33.30  77.50  9.00  8.30  97  4.00  0.20  0.00
# 8   6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00
# 8   6   aug  sun 92.30  85.30 488.00 14.70 22.20  29  5.40  0.00  0.00
# 8   6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00
# 8   6   aug  mon 91.50 145.40 608.20 10.70  8.00  86  2.20  0.00  0.00
# 8   6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 22.80  40  4.00  0.00  0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00
# 7   5   sep  sat 92.80  73.20 713.00 22.60 19.30  38  4.00  0.00  0.00
# ...

# %% [markdown]
# ** Conditional Data fetching **

# %%
df.head(2)
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.20 26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 1  7  4   oct  tue 90.60 35.40 669.10 6.70 18.00  33  0.90  0.00  0.00

# %%
#'area' is greater than 0, 'wind' is greater than 1 and the 'temp' is greater than 15

df[(df["area"] > 0) & (df["wind"] > 1) & (df["temp"] > 15)]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 138  9  9   jul  tue 85.80  48.30 313.40  3.90 18.00  42  2.70  0.00   0.36
# 139  1  4   sep  tue 91.00 129.50 692.60  7.00 21.70  38  2.20  0.00   0.43
# 140  2  5   sep  mon 90.90 126.50 686.50  7.00 21.90  39  1.80  0.00   0.47
# 141  1  2   aug  wed 95.50  99.90 513.30 13.20 23.30  31  4.50  0.00   0.55
# 142  8  6   aug  fri 90.10 108.00 529.80 12.50 21.20  51  8.90  0.00   0.61
# 143  1  2   jul  sat 90.00  51.30 296.30  8.70 16.60  53  5.40  0.00   0.71
# 144  2  5   aug  wed 95.50  99.90 513.30 13.20 23.80  32  5.40  0.00   0.77
# 145  6  5   aug  thu 95.20 131.70 578.80 10.40 27.40  22  4.00  0.00   0.90
# 147  8  3   sep  tue 84.40  73.40 671.90  3.20 24.20  28  3.60  0.00   0.96
# 148  2  2   aug  tue 94.80 108.30 647.10 17.00 17.40  43  6.70  0.00   1.07
# 149  8  6   sep  thu 93.70  80.90 685.20 17.90 23.70  25  4.50  0.00   1.12
# ...

# %%
day = ["sun", "sat"]

df[df["day"].isin(day)].head()
# Out:
#     X  Y month  day  FFMC   DMC     DC   ISI  temp  RH  wind  rain  area
# 2   7  4   oct  sat 90.60 43.70 686.90  6.70 14.60  33  1.30  0.00  0.00
# 4   8  6   mar  sun 89.30 51.30 102.20  9.60 11.40  99  1.80  0.00  0.00
# 5   8  6   aug  sun 92.30 85.30 488.00 14.70 22.20  29  5.40  0.00  0.00
# 9   7  5   sep  sat 92.50 88.00 698.60  7.10 22.80  40  4.00  0.00  0.00
# 10  7  5   sep  sat 92.50 88.00 698.60  7.10 17.80  51  7.20  0.00  0.00

# %%
df_1 = pd.read_csv('DataSet/restaurant-1.csv')
df_2 = pd.read_csv('DataSet/restaurant-1.csv')

# %%
df_1.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id
# 0     "steakhouses"       '0'
# 1           "delis"       '1'
# 2     "californian"       '2'
# 3   "french bistro"       '3'
# 4     "californian"       '4'

# %%
df_2.head()
# Out:
#                         name                     address             city  \
# 0  arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                 art's deli       "12224 ventura blvd."    "studio city"
# 2              bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                 cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                  campanile       "624 s. la brea ave."    "los angeles"
#
#             cuisine unique_id
# 0     "steakhouses"       '0'
# 1           "delis"       '1'
# 2     "californian"       '2'
# 3   "french bistro"       '3'
# 4     "californian"       '4'

# %%
df_3 = pd.merge(df_1,df_2, how='inner', on='unique_id')

# %%
df1
# Out:
#     Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# X
# 7   5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00
# 7   4   oct  tue 90.60  35.40 669.10  6.70 18.00  33  0.90  0.00  0.00
# 7   4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00
# 8   6   mar  fri 91.70  33.30  77.50  9.00  8.30  97  4.00  0.20  0.00
# 8   6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00
# 8   6   aug  sun 92.30  85.30 488.00 14.70 22.20  29  5.40  0.00  0.00
# 8   6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00
# 8   6   aug  mon 91.50 145.40 608.20 10.70  8.00  86  2.20  0.00  0.00
# 8   6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 22.80  40  4.00  0.00  0.00
# 7   5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00
# 7   5   sep  sat 92.80  73.20 713.00 22.60 19.30  38  4.00  0.00  0.00
# ...

# %%
df_1.merge(df_2, how="inner", on ="unique_id")
# Out:
#                                        name_x                     address_x  \
# 0                   arnie morton's of chicago     "435 s. la cienega blvd."
# 1                                  art's deli         "12224 ventura blvd."
# 2                               bel-air hotel        "701 stone canyon rd."
# 3                                  cafe bizou         "14016 ventura blvd."
# 4                                   campanile         "624 s. la brea ave."
# 5                             chinois on main               "2709 main st."
# 6                                      citrus           "6703 melrose ave."
# 7                         fenix at the argyle           "8358 sunset blvd."
# 8                                     granita         "23725 w. malibu rd."
# 9                                  grill  the             "9560 dayton way"
# 10                                      katsu         "1972 hillhurst ave."
# ...

# %%
df1 = pd.DataFrame(data={"Name" : ["Pravin", "Amol", "Rakesh"],
                        "Age" : [20,25,35],
                        "Sal" : [100,123,567]})

# %%
df2 = pd.DataFrame(data={"Name" : ["Pawar", "Mane", "Lobo"],
                        "Age" : [20,25,30]})

# %%
df1.append(df2, ignore_index=True)
# Out:
#    Age    Name    Sal
# 0   20  Pravin 100.00
# 1   25    Amol 123.00
# 2   35  Rakesh 567.00
# 3   20   Pawar    nan
# 4   25    Mane    nan
# 5   30    Lobo    nan

# %%
df1.append(df2, )
# Out:
#    Age    Name    Sal
# 0   20  Pravin 100.00
# 1   25    Amol 123.00
# 2   35  Rakesh 567.00
# 0   20   Pawar    nan
# 1   25    Mane    nan
# 2   30    Lobo    nan

# %%
df1.merge(df2, on="Age", how="left")
# Out:
#    Age  Name_x    Sal Name_y
# 0   20  Pravin 100.00  Pawar
# 1   25    Amol 123.00   Mane
# 2   30     NaN    nan   Lobo

# %%
pd.concat([df1,df2], axis=0)
# Out:
#    Age    Name    Sal
# 0   20  Pravin 100.00
# 1   25    Amol 123.00
# 2   30  Rakesh 567.00
# 0   20   Pawar    nan
# 1   25    Mane    nan
# 2   30    Lobo    nan

# %%
df3=pd.concat([df1,df2], axis=1)
df3
# Out:
#    Age    Name  Sal  Age   Name
# 0   20  Pravin  100   20  Pawar
# 1   25    Amol  123   25   Mane
# 2   30  Rakesh  567   30   Lobo

# %%
df3["Age"]
# Out:
#    Age  Age
# 0   20   20
# 1   25   25
# 2   30   30

# %%
df1.add(df2)
# Out:
#    Age         Name  Sal
# 0   40  PravinPawar  nan
# 1   50     AmolMane  nan
# 2   60   RakeshLobo  nan

# %%
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

# %%
allMedals = gold.merge(silver, how="outer", on="Country")
allMedals = allMedals.merge(bronze, how="outer", on="Country")
allMedals.fillna(value=0, inplace=True)
allMedals["Total"] = allMedals["Medals_x"] + allMedals["Medals_y"] + allMedals["Medals"]
allMedals.sort_values(by="Total", ascending=False)
# Out:
#    Country  Medals_x  Medals_y  Medals  Total
# 0      USA     15.00     29.00   28.00  72.00
# 1   France     13.00      0.00   40.00  53.00
# 4       UK      0.00      0.00   27.00  27.00
# 2   Russia      9.00     16.00    0.00  25.00
# 3  Germany      0.00     20.00    0.00  20.00

# %%
resultDF = pd.DataFrame(data=allMedals, columns=["Country","Total"])
resultDF.set_index("Country", inplace=True)
resultDF.rename(columns={"Total":"Medals"}, inplace=True)

# %%
df1.head()
# Out:
#    Age    Name  Sal
# 0   20  Pravin  100
# 1   25    Amol  123
# 2   30  Rakesh  567

# %%
df_1 = pd.read_csv('DataSet/forestfires.csv')
df_1.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.20 26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 1  7  4   oct  tue 90.60 35.40 669.10 6.70 18.00  33  0.90  0.00  0.00
# 2  7  4   oct  sat 90.60 43.70 686.90 6.70 14.60  33  1.30  0.00  0.00
# 3  8  6   mar  fri 91.70 33.30  77.50 9.00  8.30  97  4.00  0.20  0.00
# 4  8  6   mar  sun 89.30 51.30 102.20 9.60 11.40  99  1.80  0.00  0.00

# %%
groupDf = df_1.groupby(by=["month","day"])
df_result =  groupDf[["rain", "wind"]].min() 

pd.options.display.float_format = '{:.2f}'.format
print(df_1.head())
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri 86.20 26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 1  7  4   oct  tue 90.60 35.40 669.10 6.70 18.00  33  0.90  0.00  0.00
# 2  7  4   oct  sat 90.60 43.70 686.90 6.70 14.60  33  1.30  0.00  0.00
# 3  8  6   mar  fri 91.70 33.30  77.50 9.00  8.30  97  4.00  0.20  0.00
# 4  8  6   mar  sun 89.30 51.30 102.20 9.60 11.40  99  1.80  0.00  0.00

# %%
df['XY'] = df['X'] * df['Y']
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  XY
# 0  7  5   mar  fri 86.20 26.20  94.30 5.10  8.20  51  6.70  0.00  0.00  35
# 1  7  4   oct  tue 90.60 35.40 669.10 6.70 18.00  33  0.90  0.00  0.00  28
# 2  7  4   oct  sat 90.60 43.70 686.90 6.70 14.60  33  1.30  0.00  0.00  28
# 3  8  6   mar  fri 91.70 33.30  77.50 9.00  8.30  97  4.00  0.20  0.00  48
# 4  8  6   mar  sun 89.30 51.30 102.20 9.60 11.40  99  1.80  0.00  0.00  48

# %% [markdown]
# ** Apply Function to Data Frame **

# %%
#take sample data set
df1 = df.take(range(0,40,2))
df1
# Out:
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area  XY
# 0   7  5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00  35
# 2   7  4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00  28
# 4   8  6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00  48
# 6   8  6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00  48
# 8   8  6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00  48
# 10  7  5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00  35
# 12  6  5   aug  fri 63.50  70.80 665.30  0.80 17.00  72  6.70  0.00  0.00  30
# 14  6  5   sep  wed 92.90 133.30 699.60  9.20 26.40  21  4.50  0.00  0.00  30
# 16  5  5   mar  sat 91.70  35.80  80.80  7.80 15.10  27  5.40  0.00  0.00  25
# 18  6  4   mar  wed 89.20  27.90  70.80  6.30 15.90  35  4.00  0.00  0.00  24
# 20  6  4   sep  tue 91.00 129.50 692.60  7.00 18.30  40  2.70  0.00  0.00  24
# ...

# %%
df1.describe()
# Out:
#           X     Y  FFMC    DMC     DC   ISI  temp    RH  wind  rain  area  \
# count 20.00 20.00 20.00  20.00  20.00 20.00 20.00 20.00 20.00 20.00 20.00
# mean   6.60  4.25 89.98  81.82 532.12 10.80 19.12 39.85  4.21  0.00  0.00
# std    0.82  1.07  6.55  40.10 256.25 11.40  5.37 19.43  1.75  0.00  0.00
# min    5.00  3.00 63.50  26.20  70.80  0.80  8.20 21.00  1.30  0.00  0.00
# 25%    6.00  3.00 90.27  43.70 421.70  6.70 15.70 27.00  2.70  0.00  0.00
# 50%    6.50  4.00 91.35  81.80 678.00  7.45 18.65 33.50  4.25  0.00  0.00
# 75%    7.00  5.00 92.60 120.80 694.10  9.30 22.20 45.75  5.50  0.00  0.00
# max    8.00  6.00 94.30 145.40 724.30 56.10 30.20 99.00  7.20  0.00  0.00
#
#          XY
# count 20.00
# mean  28.50
# std    9.98
# min   18.00
# 25%   20.25
# 50%   28.00
# 75%   31.25
# max   48.00

# %%
def tempCategory(t):
    cat = ""
    if t < 10 :
        cat = "Cold"
    elif t>= 10 and t < 20 :
        cat = "Normal"
    else:
        cat = "Hot"
    return cat

# %%
df1["TempCat"] = df["temp"].apply(tempCategory)
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area  XY  \
# 0   7  5   mar  fri 86.20  26.20  94.30  5.10  8.20  51  6.70  0.00  0.00  35
# 2   7  4   oct  sat 90.60  43.70 686.90  6.70 14.60  33  1.30  0.00  0.00  28
# 4   8  6   mar  sun 89.30  51.30 102.20  9.60 11.40  99  1.80  0.00  0.00  48
# 6   8  6   aug  mon 92.30  88.90 495.60  8.50 24.10  27  3.10  0.00  0.00  48
# 8   8  6   sep  tue 91.00 129.50 692.60  7.00 13.10  63  5.40  0.00  0.00  48
# 10  7  5   sep  sat 92.50  88.00 698.60  7.10 17.80  51  7.20  0.00  0.00  35
# ...

# %%
df1['XY'] = df1['X'] * df1['Y']
df1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  area  XY  \
# 0  7  5   mar  fri 86.20  26.20  94.30 5.10  8.20  51  6.70  0.00  0.00  35
# 2  7  4   oct  sat 90.60  43.70 686.90 6.70 14.60  33  1.30  0.00  0.00  28
# 4  8  6   mar  sun 89.30  51.30 102.20 9.60 11.40  99  1.80  0.00  0.00  48
# 6  8  6   aug  mon 92.30  88.90 495.60 8.50 24.10  27  3.10  0.00  0.00  48
# 8  8  6   sep  tue 91.00 129.50 692.60 7.00 13.10  63  5.40  0.00  0.00  48
#
#   TempCat
# 0    Cold
# 2  Normal
# 4  Normal
# 6     Hot
# 8  Normal

# %%
del df1['XY']

# %%
df1.head()
# Out:
#    X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  area  \
# 0  7  5   mar  fri 86.20  26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 2  7  4   oct  sat 90.60  43.70 686.90 6.70 14.60  33  1.30  0.00  0.00
# 4  8  6   mar  sun 89.30  51.30 102.20 9.60 11.40  99  1.80  0.00  0.00
# 6  8  6   aug  mon 92.30  88.90 495.60 8.50 24.10  27  3.10  0.00  0.00
# 8  8  6   sep  tue 91.00 129.50 692.60 7.00 13.10  63  5.40  0.00  0.00
#
#   TempCat
# 0    Cold
# 2  Normal
# 4  Normal
# 6     Hot
# 8  Normal

# %%
df1['XY'] = df1.apply(lambda r : r['X'] * r['Y'], axis = 1)
df1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  area  \
# 0  7  5   mar  fri 86.20  26.20  94.30 5.10  8.20  51  6.70  0.00  0.00
# 2  7  4   oct  sat 90.60  43.70 686.90 6.70 14.60  33  1.30  0.00  0.00
# 4  8  6   mar  sun 89.30  51.30 102.20 9.60 11.40  99  1.80  0.00  0.00
# 6  8  6   aug  mon 92.30  88.90 495.60 8.50 24.10  27  3.10  0.00  0.00
# 8  8  6   sep  tue 91.00 129.50 692.60 7.00 13.10  63  5.40  0.00  0.00
#
#   TempCat  XY
# 0    Cold  35
# 2  Normal  28
# 4  Normal  48
# 6     Hot  48
# 8  Normal  48

# %% [markdown]
# ** Pivot **

# %%
df.pivot_table(values=["rain","wind"], index=["month", "day"], aggfunc="mean")
# Out:
#            rain  wind
# month day
# apr   fri  0.00  3.10
#       mon  0.00  3.10
#       sat  0.00  4.50
#       sun  0.00  5.67
#       thu  0.00  5.80
#       wed  0.00  2.70
# aug   fri  0.07  4.77
#       mon  0.00  2.87
#       sat  0.00  4.31
#       sun  0.03  4.42
#       thu  0.00  3.50
#       tue  0.30  4.57
#       wed  0.00  3.52
# dec   fri  0.00  4.90
#       mon  0.00  8.50
#       sun  0.00  8.50
#       thu  0.00  4.90
#       tue  0.00  8.50
#       wed  0.00  8.00
# feb   fri  0.00  4.82
#       mon  0.00  4.50
#       sat  0.00  2.35
#       sun  0.00  2.55
#       thu  0.00  3.10
#       tue  0.00  5.85
#       wed  0.00  3.10
# jan   sat  0.00  3.10
#       sun  0.00  0.90
# jul   fri  0.00  4.30
#       mon  0.00  3.80
# ...         ...   ...
#       wed  0.07  6.27
# jun   fri  0.00  4.80
#       mon  0.00  4.77
#       sat  0.00  2.90
#       sun  0.00  2.45
#       thu  0.00  6.05
#       wed  0.00  4.63
# mar   fri  0.02  5.86
#       mon  0.00  4.08
# ...

# %% [markdown]
# ** Missing Values **

# %%
df = pd.read_csv('DataSet/market_fact.csv')
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01           23.00
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818   42.27      0.01           13.00
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818 4701.69      0.00           26.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818 2337.89      0.09           43.00
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818 4233.15      0.08           35.00
#
#    Profit  Shipping_Cost  Product_Base_Margin
# 0  -30.51           3.60                 0.56
# 1    4.56           0.93                 0.54
# 2 1148.90           2.50                 0.59
# 3  729.34          14.30                 0.37
# 4 1219.87          26.30                 0.38

# %%
df.isnull().sum()
# Out:
# Ord_id                   0
# Prod_id                  0
# Ship_id                  0
# Cust_id                  0
# Sales                   20
# Discount                55
# Order_Quantity          55
# Profit                  55
# Shipping_Cost           55
# Product_Base_Margin    109
# dtype: int64

# %%
df.isnull().sum() / df.isnull().count() * 100
# Out:
# Ord_id                0.00
# Prod_id               0.00
# Ship_id               0.00
# Cust_id               0.00
# Sales                 0.24
# Discount              0.65
# Order_Quantity        0.65
# Profit                0.65
# Shipping_Cost         0.65
# Product_Base_Margin   1.30
# dtype: float64

# %%
# Remove the missing values from the rows having greater than 5 missing values
print(df.isnull().sum())
df1 = df.dropna(thresh=5, axis=0)
print(df1.isnull().sum())
# Out:
# Ord_id                   0
# Prod_id                  0
# Ship_id                  0
# Cust_id                  0
# Sales                   20
# Discount                55
# Order_Quantity          55
# Profit                  55
# Shipping_Cost           55
# Product_Base_Margin    109
# dtype: int64
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount               35
# Order_Quantity         35
# Profit                 35
# Shipping_Cost          35
# Product_Base_Margin    89
# dtype: int64

# %%
print(df.isnull().sum())
df["Product_Base_Margin"].fillna(value=df["Product_Base_Margin"].mean(), inplace=True)
print(df.isnull().sum())
# Out:
# Ord_id                   0
# Prod_id                  0
# Ship_id                  0
# Cust_id                  0
# Sales                   20
# Discount                55
# Order_Quantity          55
# Profit                  55
# Shipping_Cost           55
# Product_Base_Margin    109
# dtype: int64
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                  20
# Discount               55
# Order_Quantity         55
# Profit                 55
# Shipping_Cost          55
# Product_Base_Margin     0
# dtype: int64

# %%
df1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.16      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641   162.00      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641    57.22      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.01      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708   465.90      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04
# 13    Ord_2207  Prod_11  SHP_3093   Cust_839  3364.25      0.10
# ...
